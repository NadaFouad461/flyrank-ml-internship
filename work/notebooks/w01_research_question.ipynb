# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/NadaFouad461/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I choose the Refresh / Content Opportunity Scoring lane. I want to identify which content pages should be reviewed first based on observable search and engagement signals. I chose this lane because the starter dataset contains useful signals for understanding which pages may deserve review, and the final result can support a practical ranked review queue.

# %%
print("Lane: Refresh / Content Opportunity Scoring")
# Out:
# Lane: Refresh / Content Opportunity Scoring

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The decision is which content page should be reviewed first. A content or SEO reviewer would use the ranked output to prioritize limited review and refresh time. A wrong recommendation could waste reviewer time on a low-value page or cause a more important page to be missed.

# %%
print("Decision: prioritize pages for review")
print("User: content or SEO reviewer")
print("Main risk: wasted review time or missed high-value pages")
# Out:
# Decision: prioritize pages for review
# User: content or SEO reviewer
# Main risk: wasted review time or missed high-value pages

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains 30,000 content items and 44 columns. The average number of impressions over the 90-day window is 5,200.37. This gives enough observed data and search-performance signals to continue investigating which pages may deserve review first.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/NadaFouad461/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)
print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))
print("Average impressions:", round(df["impressions_90d"].mean(), 2))
# Out:
# Number of rows: 30000
# Number of columns: 44
# Average impressions: 5200.37

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This work will provide observed and measured evidence from the available anonymized data and may produce directional, decision-support recommendations for prioritizing content review. It will not provide causal proof that refreshing a page causes better performance, and it will not claim to predict Google's algorithm.

# %%
print("Claims: observed, measured, directional, decision-support")
print("Not claimed: causal proof or predicting Google's algorithm")
# Out:
# Claims: observed, measured, directional, decision-support
# Not claimed: causal proof or predicting Google's algorithm

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
